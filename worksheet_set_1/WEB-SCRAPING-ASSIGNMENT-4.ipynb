# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# %% [markdown]
# # ANS-1-A python program to scrape details of most viewed videos on youtube from wikipedia

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up wikipedia.org website on automated chrome window
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
#let's extract all web elements having name
name=[]
name_tags=driver.find_elements(By.XPATH,'//a[@class="mw-redirect"]')
for i in name_tags:
    name.append(i.text)
name
# Out:
# ['music videos',
#  'regional restrictions',
#  'Baby Shark Dance',
#  'Johny Johny Yes Papa',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'Alan Walker',
#  'Baby Shark Dance',
#  'Baby Shark Dance',
#  'Johny Johny Yes Papa',
#  'Baby Shark Dance',
#  'List of most-viewed online trailers in the first 24 hours',
#  'Wired',
#  'CNet',
#  '',
#  '',
#  '',
#  '']

# %%
#let's extract all web elements having artist
artist=[]
artist_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[1]/td[3]/a')
for i in artist_tags:
    artist.append(i.text)
artist
# Out:
# ["Pinkfong Baby Shark - Kids' Songs & Stories"]

# %%
#let's extract all web elements having artist
artist=[]
artist_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[2]/td[3]/a')
for i in artist_tags:
    artist.append(i.text)
artist
# Out:
# ['Luis Fonsi']

# %%
#let's extract all web elements having artist
artist=[]
artist_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[3]/td[3]')
for i in artist_tags:
    artist.append(i.text)
artist
# Out:
# ['LooLoo Kids']

# %%
#let's extract all web elements having artist
artist=[]
artist_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[4]/td[3]/a')
for i in artist_tags:
    artist.append(i.text)
artist
# Out:
# ['Ed Sheeran']

# %%
#let's extract all web elements having artist
artist=[]
artist_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[5]/td[3]/a')
for i in artist_tags:
    artist.append(i.text)
artist
# Out:
# ['Cocomelon – Nursery Rhymes']

# %%
#let's extract all web elements having date
date=[]
date_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[1]/td[5]')
for i in date_tags:
    date.append(i.text)
date
# Out:
# ['June 17, 2016']

# %%
#let's extract all web elements having date
date=[]
date_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[2]/td[5]')
for i in date_tags:
    date.append(i.text)
date
# Out:
# ['January 12, 2017']

# %%
#let's extract all web elements having date
date=[]
date_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[3]/td[5]')
for i in date_tags:
    date.append(i.text)
date
# Out:
# ['October 8, 2016']

# %%
#let's extract all web elements having date
date=[]
date_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[4]/td[5]')
for i in date_tags:
    date.append(i.text)
date
# Out:
# ['January 30, 2017']

# %%
#let's extract all web elements having date
date=[]
date_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[5]/td[5]')
for i in date_tags:
    date.append(i.text)
date
# Out:
# ['May 2, 2018']

# %%
#let's extract all web elements having view
view=[]
view_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[1]/td[4]')
for i in view_tags:
    view.append(i.text)
view
# Out:
# ['11.74']

# %%
#let's extract all web elements having view
view=[]
view_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[2]/td[4]')
for i in view_tags:
    view.append(i.text)
view
# Out:
# ['8.01']

# %%
#let's extract all web elements having view
view=[]
view_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[3]/td[4]')
for i in view_tags:
    view.append(i.text)
view
# Out:
# ['6.53']

# %%
#let's extract all web elements having view
view=[]
view_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[4]/td[4]')
for i in view_tags:
    view.append(i.text)
view
# Out:
# ['5.85']

# %%
#let's extract all web elements having view
view=[]
view_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[5]/td[4]')
for i in view_tags:
    view.append(i.text)
view
# Out:
# ['5.77']

# %%
driver.close()

# %% [markdown]
# # ANS-2-A python program to scrape details from bcci.tv.

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up bcci.tv. website on automated chrome window
url='https://www.bcci.tv/'
driver.get(url)

# %%
#let's extract all web elements having title
title=[]
title_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
for i in title_tags:
    title.append(i.text)
title
# Out:
# ['INDIA A IN BANGLADESH MULTI DAY SERIES',
#  'Stumps Day 1',
#  'INDIA TOUR OF BANGLADESH ODI SERIES 2022-23',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'INDIA TOUR OF BANGLADESH ODI SERIES 2022-23',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'INDIA TOUR OF BANGLADESH TEST SERIES 2022-23',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022']

# %%
#let's extract all web elements having place
place=[]
place_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
for i in place_tags:
    place.append(i.text)
place
# Out:
# ['(80.5 ov)',
#  '(4.0 ov)',
#  'Sylhet International Cricket Stadium,',
#  'Shere Bangla National Stadium, Mirpur,',
#  'DY Patil Stadium,',
#  'Zahur Ahmed Chowdhury Stadium,',
#  'DY Patil Stadium,',
#  'Zahur Ahmed Chowdhury Stadium,',
#  'Brabourne - CCI,',
#  'Brabourne - CCI,']

# %%
#let's extract all web elements having date
date=[]
date_tags=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
for i in date_tags:
    date.append(i.text)
date
# Out:
# ['6 DEC 2022',
#  '7 DEC 2022',
#  '9 DEC 2022',
#  '10 DEC 2022',
#  '11 DEC 2022',
#  '14 DEC 2022',
#  '14 DEC 2022',
#  '17 DEC 2022']

# %%
#let's extract all web elements having time
time=[]
time_tags=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
for i in time_tags:
    time.append(i.text)
time
# Out:
# ['11:30 AM IST',
#  '7:00 PM IST',
#  '11:30 AM IST',
#  '7:00 PM IST',
#  '9:30 AM IST',
#  '7:00 PM IST',
#  '7:00 PM IST']

# %%
driver.close()

# %% [markdown]
# # ANS-4-A python program to scrape details from statisticstime.com

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up statisticstime.com website on automated chrome window
url='https://statisticstimes.com/'
driver.get(url)

# %%
#clicking the Economy button
economy_btn=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy_btn.click()

# %%
#clicking the states button
states_btn=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
states_btn.click()

# %%
#let's extract all web elements having data
data=[]
data_tags=driver.find_elements(By.XPATH,'//html[@class="st-dom-reset"]')
for i in data_tags:
    data.append(i.text)
data
# Out:
# ["Home\nEconomy\nDemographics\nCoronavirus\nPolitics\nGeography\nTech\nSports\nRanking\nArticle\nIndian states by GDP\nSource Ministry of Statistics and Programme Implementation\nLast Updated 01 Mar 2021\nTop Statistics\nOlympics Medal Table 2020\nList of continents by gdp per capita\nWorld urban population\nSee Also:\n» GDP Growth of Indian states\n» GDP per capita of Indian states\n» Sectorwise GDP of Indian states\n» Comparing Indian states and Countries by GDP\n» GDP-Population-Area relationship of Indian states\nView More Economy Statistics\nMaharashtra has the highest GSDP among 33 Indian States and Union Territories. As of the FY 2018-19, Maharashtra contributes 13.88% of India's GDP at current prices, followed by Tamil Nadu (8.59%) and the most populous state Uttar Pradesh (8.35%). Other states in top 5 are Gujarat (7.92%) andKarnataka (7.87%).\nIndia's largest state Rajasthan is at number 7, behind West Bengal, poorest state Bihar is at number 14, and capital Delhi is at num
# ...

# %%
driver.close()

# %% [markdown]
# # ANS-5-A python program to scrape details from github.com

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up github.com website on automated chrome window
url='https://github.com/'
driver.get(url)

# %%
#clicking the menu button
menu_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[1]/div[2]/button/span/span')
menu_btn.click()

# %%
#clicking the open button
open_btn=driver.find_element(By.XPATH,'//a[@class="HeaderMenu-link no-underline px-0 px-lg-2 py-3 py-lg-2 d-block d-lg-inline-block"]')
open_btn.click()

# %%
#let's extract all web elements having title
title=[]
title_tags=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
for i in title_tags:
    title.append(i.text)
title
# Out:
# ['wong2 / chat-gpt-google-extension',
#  'mpociot / chatgpt-vscode',
#  'acheong08 / ChatGPT',
#  'vincelwt / chatgpt-mac',
#  'monicahq / monica',
#  'max-sixty / aoc-gpt',
#  'transitive-bullshit / chatgpt-api',
#  'altryne / chatGPT-telegram-bot',
#  'm1guelpf / chatgpt-telegram',
#  'xiaolincoder / CS-Base',
#  'Visualize-ML / Book4_Power-of-Matrix',
#  'hehonghui / awesome-english-ebooks',
#  'hodgesmr / mastodon_digest',
#  'openai / openai-quickstart-node',
#  'invoke-ai / InvokeAI',
#  'iamadamdev / bypass-paywalls-chrome',
#  'jerryjliu / gpt_index',
#  'halo-dev / halo',
#  'taranjeet / chatgpt-api',
#  'evrone / go-clean-template',
#  'mmabrouk / chatgpt-wrapper',
#  'flutter / flutter',
#  'timqian / chinese-independent-blogs',
#  'gothinkster / realworld',
#  'MariaLetta / free-gophers-pack']

# %%
#let's extract all web elements having description
description=[]
description_tags=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in description_tags:
    description.append(i.text)
description
# Out:
# ['A browser extension to display ChatGPT response alongside Google Search results',
#  'A VSCode extension that allows you to use ChatGPT',
#  "Lightweight package for interacting with ChatGPT's API by OpenAI. Uses reverse engineered official API.",
#  'ChatGPT for Mac, living in your menubar.',
#  'Personal CRM. Remember everything about your friends, family and business relationships.',
#  'Solve Advent of Code puzzles with GPT-3',
#  'Node.js client for the unofficial ChatGPT API.',
#  'This is a very early attempt at having chatGPT work within a telegram bot',
#  'Run your own GPTChat Telegram bot, with a single command!',
#  '图解计算机网络、操作系统、计算机组成、数据库，共 1000 张图 + 50 万字，破除晦涩难懂的计算机基础知识，让天下没有难懂的八股文！🚀 在线阅读：https://xiaolincoding.com',
#  'Book_4_《矩阵力量》 | 鸢尾花书：从加减乘除到机器学习；本册有，584幅图，81个代码文件，其中18个Streamlit App；状态：清华社五审五校中；Github稿件基本稳定，欢迎提意见，会及时修改',
#  '经济学人(含音频)、纽约客、卫报、连线、大西洋月刊等英语杂志免费下载,支持epub、mobi、pdf格式, 每周更新',
# ...

# %%
#let's extract all web elements having language
language=[]
language_tags=driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
for i in language_tags:
    language.append(i.text)
language
# Out:
# ['CSS',
#  'TypeScript',
#  'Python',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'TypeScript',
#  'Python',
#  'Go',
#  'Python',
#  'CSS',
#  'Python',
#  'JavaScript',
#  'Jupyter Notebook',
#  'JavaScript',
#  'Python',
#  'Java',
#  'Python',
#  'Go',
#  'Python',
#  'Dart',
#  'JavaScript',
#  'TypeScript',
#  'Go']

# %%
#let's extract all web elements having contributor
contributor=[]
contributor_tags=driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')
for i in contributor_tags:
    contributor.append(i.text)
contributor
# Out:
# ['3,843',
#  '175',
#  '973',
#  '54',
#  '2,706',
#  '226',
#  '857',
#  '43',
#  '18,240',
#  '1,814',
#  '355',
#  '18',
#  '1,085',
#  '84',
#  '519',
#  '64',
#  '901',
#  '68',
#  '3,355',
#  '524',
#  '1,191',
#  '149',
#  '2,407',
#  '202',
#  '159',
#  '8',
#  '385',
#  '285',
#  '7,389',
#  '838',
#  '31,428',
#  '2,309',
#  '302',
#  '14',
#  '24,756',
#  '8,114',
#  '405',
#  '55',
#  '4,170',
#  '321',
#  '203',
#  '18',
#  '147,010',
#  '23,913',
#  '10,706',
#  '1,590',
#  '70,637',
#  '6,616',
#  '2,780',
#  '168']

# %%
driver.close()

# %% [markdown]
# # ANS-6-A python program to scrape details from billiboard.com

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up billiboard.com website on automated chrome window
url='https://www.billboard.com/'
driver.get(url)

# %%
#clicking the chart button
chart_btn=driver.find_element(By.XPATH,'//a[@class="c-link  lrv-a-unstyle-link a-font-primary-bold lrv-u-font-size-28@desktop-xl lrv-u-font-size-18 lrv-u-color-grey:hover u-padding-a-1@desktop-max lrv-u-padding-b-050"]')
chart_btn.click()

# %%
#let's extract all web elements having name
name=[]
name_tags=driver.find_elements(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]')
for i in name_tags:
    name.append(i.text)
name
# Out:
# ['All I Want For Christmas Is You',
#  "Rockin' Around The Christmas Tree",
#  'Unholy',
#  'Jingle Bell Rock',
#  'A Holly Jolly Christmas',
#  'Rich Flex',
#  'Bad Habit',
#  "It's The Most Wonderful Time Of The Year",
#  'Last Christmas',
#  "I'm Good (Blue)",
#  'The Christmas Song (Merry Christmas To You)',
#  'Feliz Navidad',
#  'As It Was',
#  'Die For You',
#  'Sleigh Ride',
#  'Underneath The Tree',
#  'Let It Snow, Let It Snow, Let It Snow',
#  "It's Beginning To Look A Lot Like Christmas",
#  'Cuff It',
#  'Under The Influence',
#  'Lift Me Up',
#  'Christmas (Baby Please Come Home)',
#  'Santa Tell Me',
#  'You Proof',
#  'Super Freaky Girl',
#  'I Like You (A Happier Song)',
#  'Something In The Orange',
#  "It's Beginning To Look A Lot Like Christmas",
#  'Deck The Halls',
#  'White Christmas',
#  'Wasted On You',
#  'Jingle Bells',
#  'Rudolph The Red-Nosed Reindeer',
#  'Just Wanna Rock',
#  'Made You Look',
#  'Tomorrow 2',
#  'Vegas',
# ...

# %%
#let's extract all web elements having artist
artist=[]
artist_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
for i in artist_tags:
    artist.append(i.text)
artist
# Out:
# ['Mariah Carey',
#  'Brenda Lee',
#  'Sam Smith & Kim Petras',
#  'Bobby Helms',
#  'Burl Ives',
#  'Drake & 21 Savage',
#  'Steve Lacy',
#  'Andy Williams',
#  'Wham!',
#  'David Guetta & Bebe Rexha',
#  'Nat King Cole',
#  'Jose Feliciano',
#  'Harry Styles',
#  'The Weeknd',
#  'The Ronettes',
#  'Kelly Clarkson',
#  'Dean Martin',
#  'Perry Como And The Fontane Sisters With Mitchell Ayres And His Orchestra',
#  'Beyonce',
#  'Chris Brown',
#  'Rihanna',
#  'Darlene Love',
#  'Ariana Grande',
#  'Morgan Wallen',
#  'Nicki Minaj',
#  'Post Malone Featuring Doja Cat',
#  'Zach Bryan',
#  'Michael Buble',
#  'Nat King Cole',
#  'Bing Crosby',
#  'Morgan Wallen',
#  'Frank Sinatra',
#  'Gene Autry',
#  'Lil Uzi Vert',
#  'Meghan Trainor',
#  'GloRilla & Cardi B',
#  'Doja Cat',
#  'Gene Autry',
#  'Future Featuring Drake & Tems',
#  'JVKE',
#  'Thurl Ravenscroft',
#  'Elvis Presley',
#  'Bad Bunny',
#  'OneRepublic',
#  'Drake Featuring 21 Savage',
#  'Nicky Youre & dazy',
# ...

# %%
#let's extract all web elements having last week rank
lwrank=[]
lwrank_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
for i in lwrank_tags[0:100]:
    lwrank.append(i.text)
lwrank
# Out:
# ['5',
#  '1',
#  '54',
#  '',
#  '',
#  '',
#  '6',
#  '2',
#  '48',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '10',
#  '',
#  '',
#  '',
#  '9',
#  '3',
#  '45',
#  '',
#  '',
#  '',
#  '10',
#  '4',
#  '28',
#  '',
#  '',
#  '',
#  '2',
#  '2',
#  '4',
#  '',
#  '',
#  '',
#  '4',
#  '1',
#  '22',
#  '',
#  '',
#  '',
#  '19',
#  '5',
#  '29',
#  '',
#  '',
#  '',
#  '23',
#  '7',
#  '27',
#  '',
#  '',
#  '',
#  '7',
#  '7',
#  '14',
#  '',
#  '',
#  '',
#  '34',
#  '11',
#  '34',
#  '',
#  '',
#  '',
#  '42',
#  '6',
#  '22',
#  '',
#  '',
#  '',
#  '8',
#  '1',
#  '35',
#  '',
#  '',
#  '',
#  '12',
#  '12',
#  '18',
#  '',
#  '',
#  '',
#  '40',
#  '10',
#  '18',
#  '',
#  '',
#  '',
#  '48',
#  '12',
#  '17',
#  '',
#  '',
#  '',
#  '41',
#  '8',
#  '21',
#  '']

# %%
#let's extract all web elements having  peak rank
prank=[]
prank_tags=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]')
for i in prank_tags[0:100]:
    prank.append(i.text)
prank
# Out:
# ['',
#  '1',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '1',
#  '',
#  '3',
#  '',
#  '4',
#  '',
#  '2',
#  '',
#  '1',
#  '',
#  '5',
#  '',
#  '7',
#  '',
#  '7',
#  '',
#  '11',
#  '',
#  '6',
#  '',
#  '1',
#  '',
#  '12',
#  '',
#  '10',
#  '',
#  '12',
#  '',
#  '8',
#  '',
#  '12',
#  '',
#  '13',
#  '',
#  '14',
#  '',
#  '2',
#  '',
#  '16',
#  '',
#  '17',
#  '',
#  '5',
#  '',
#  '1',
#  '',
#  '3',
#  '',
#  '12',
#  '',
#  '20',
#  '',
#  '30',
#  '',
#  '12',
#  '',
#  '9',
#  '',
#  '33',
#  '',
#  '16',
#  '',
#  '21',
#  '',
#  '24',
#  '',
#  '9',
#  '',
#  '10',
#  '',
#  '26',
#  '',
#  '1',
#  '',
#  '35',
#  '',
#  '32',
#  '',
#  '33',
#  '',
#  '5',
#  '',
#  '6',
#  '',
#  '1',
#  '',
#  '4',
#  '',
#  '1',
#  '',
#  '41',
#  '',
#  '16']

# %%
#let's extract all web elements having weeks on board
wb=[]
wb_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
for i in wb_tags[0:100]:
    wb.append(i.text)
wb
# Out:
# ['5',
#  '1',
#  '54',
#  '',
#  '',
#  '',
#  '6',
#  '2',
#  '48',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '10',
#  '',
#  '',
#  '',
#  '9',
#  '3',
#  '45',
#  '',
#  '',
#  '',
#  '10',
#  '4',
#  '28',
#  '',
#  '',
#  '',
#  '2',
#  '2',
#  '4',
#  '',
#  '',
#  '',
#  '4',
#  '1',
#  '22',
#  '',
#  '',
#  '',
#  '19',
#  '5',
#  '29',
#  '',
#  '',
#  '',
#  '23',
#  '7',
#  '27',
#  '',
#  '',
#  '',
#  '7',
#  '7',
#  '14',
#  '',
#  '',
#  '',
#  '34',
#  '11',
#  '34',
#  '',
#  '',
#  '',
#  '42',
#  '6',
#  '22',
#  '',
#  '',
#  '',
#  '8',
#  '1',
#  '35',
#  '',
#  '',
#  '',
#  '12',
#  '12',
#  '18',
#  '',
#  '',
#  '',
#  '40',
#  '10',
#  '18',
#  '',
#  '',
#  '',
#  '48',
#  '12',
#  '17',
#  '',
#  '',
#  '',
#  '41',
#  '8',
#  '21',
#  '']

# %%
driver.close()

# %% [markdown]
# # ANS-7-A python program to scrape details from naukri.com

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up naukri.com website on automated chrome window
url='https://www.naukri.com/'
driver.get(url)

# %%
#finding web element for search product bar
search=driver.find_element(By.CLASS_NAME,"suggestor-input")
search.send_keys("Data science")

# %%
#clicking the search button
search_btn=driver.find_element(By.XPATH,'//div[@class="qsbSubmit"]')
search_btn.click()

# %%
#let's extract all web elements having name and designation
nd=[]
nd_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in nd_tags:
    nd.append(i.text)
nd
# Out:
# ['Data Science - Engineering Manager',
#  'Senior Analyst-Data Science',
#  'Paytm - Data Science - Lead',
#  'ACN - Applied Intelligence - CC - Data Science (IN) - 06',
#  'Lead Data Scientist - Data Sciences',
#  'Data Science Analyst',
#  'Analyst-Data Science',
#  'Technology Analyst / Data Science / Machine Learning',
#  'Data Science Lead - Forecasting',
#  'ACN - Applied Intelligence - Finance - Data Science - 09',
#  'ACN - Applied Intelligence - Finance - Data Science - 09',
#  'Data Science - Statistical Analyses',
#  'Python Programming Language Data Science Practitioner',
#  'Manager Data Science',
#  'Senior Data Science Engineer',
#  'ACN - Applied Intelligence - Finance - Data Science - 09',
#  'ACN - Applied Intelligence - Finance - Data Science - 09',
#  'ACN - Applied Intelligence - Finance - Data Science - 09',
#  'Analyst - Data Science - Python/Machine Learning/Analytics - KPO',
#  'Manager - Data Science - Model Development']

# %%
#let's extract all web elements having company
company=[]
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags:
    company.append(i.text)
company
# Out:
# ['Paytm',
#  'Accenture',
#  'Paytm',
#  'Accenture',
#  'GEP',
#  'Ira Commerce',
#  'Accenture',
#  'Infosys',
#  'Cargill',
#  'Accenture',
#  'Accenture',
#  'Inspiration Manpower Consultancy',
#  'Accenture',
#  'Jio',
#  'Bizongo',
#  'Accenture',
#  'Accenture',
#  'Accenture',
#  'Huquo Consulting',
#  'Xpert Conexions']

# %%
#let's extract all web elements having skills
skills=[]
skills_tags=driver.find_elements(By.XPATH,'//div[@class="job-description fs12 grey-text"]')
for i in skills_tags:
    skills.append(i.text)
skills
# Out:
# ['- We are looking for passionate and skilled data scientists to help build the next gen ...',
#  'Skill required: Data Science - Python Programming Language Designation: Senior Analyst ...',
#  'Bachelor s degree in technical/ analytics/ data science/ mathematics/ statistics/ econo...',
#  'Requirements: Responsible for taking up day-to-day activities for making deliverables t...',
#  ', code review and version control tools, batch and streaming data pipeline orchestratio...',
#  'Experience in Developing and enhancing algorithms and models to solve business problem ...',
#  'You will be required to utilize the existing frameworks, standards, patterns to create ...',
#  'Bachelor of Engineering Good understanding of the technology and domain Analytical abil...',
#  'Bachelor s degree in Computer science, Statistics, Math OR related field OR Equivalent ...',
#  'The ideal candidate should have a strong client-facing consulting background in data sc...',
# ...

# %%
#let's extract all web elements having location
location=[]
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
for i in location_tags:
    location.append(i.text)
location
# Out:
# ['New Delhi, Bangalore/Bengaluru',
#  'Mumbai',
#  'Noida, Mumbai, Bangalore/Bengaluru',
#  'Gurgaon/Gurugram',
#  'Remote',
#  'Hyderabad/Secunderabad',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad',
#  'Mumbai, Bangalore/Bengaluru',
#  'Chennai',
#  'Mumbai',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Mumbai (All Areas)']

# %%
driver.close()

# %% [markdown]
# # ANS-8-A python program to scrape details of highest selling novels.

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up theguardian.com website on automated chrome window
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'
driver.get(url)

# %%
#let's extract all web elements having name, author name, volumes sold, publisher
name=[]
name_tags=driver.find_elements(By.XPATH,'//td[@class="left"]')
for i in name_tags:
    name.append(i.text)
name
# Out:
# ['1',
#  'Brown, Dan',
#  '5,094,805',
#  'Transworld',
#  '2',
#  'Harry Potter and the Deathly Hallows',
#  'Rowling, J.K.',
#  '4,475,152',
#  'Bloomsbury',
#  '3',
#  "Harry Potter and the Philosopher's Stone",
#  'Rowling, J.K.',
#  '4,200,654',
#  'Bloomsbury',
#  '4',
#  'Harry Potter and the Order of the Phoenix',
#  'Rowling, J.K.',
#  '4,179,479',
#  'Bloomsbury',
#  '5',
#  'Fifty Shades of Grey',
#  'James, E. L.',
#  '3,758,936',
#  'Random House',
#  '6',
#  'Harry Potter and the Goblet of Fire',
#  'Rowling, J.K.',
#  '3,583,215',
#  'Bloomsbury',
#  '7',
#  'Harry Potter and the Chamber of Secrets',
#  'Rowling, J.K.',
#  '3,484,047',
#  'Bloomsbury',
#  '8',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Rowling, J.K.',
#  '3,377,906',
#  'Bloomsbury',
#  '9',
#  'Angels and Demons',
#  'Brown, Dan',
#  '3,193,946',
#  'Transworld',
#  '10',
#  "Harry Potter and the Half-blood Prince:Children's Edition",
#  'Rowling, J.K.',
#  '2,950,264',
#  'Bloomsbury',
# ...

# %%
driver.close()

# %% [markdown]
# # ANS-9-A python program to scrape details from imdb.com

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up imdb.com website on automated chrome window
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
#let's extract all web elements having name and year
name=[]
name_tags=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
for i in name_tags:
    name.append(i.text)
name
# Out:
# ['1. Game of Thrones (2011–2019)',
#  '2. Stranger Things (2016– )',
#  '3. The Walking Dead (2010–2022)',
#  '4. 13 Reasons Why (2017–2020)',
#  '5. The 100 (2014–2020)',
#  '6. Orange Is the New Black (2013–2019)',
#  '7. Riverdale (2017– )',
#  "8. Grey's Anatomy (2005– )",
#  '9. The Flash (2014–2023)',
#  '10. Arrow (2012–2020)',
#  '11. Money Heist (2017–2021)',
#  '12. The Big Bang Theory (2007–2019)',
#  '13. Black Mirror (2011–2019)',
#  '14. Sherlock (2010–2017)',
#  '15. Vikings (2013–2020)',
#  '16. Pretty Little Liars (2010–2017)',
#  '17. The Vampire Diaries (2009–2017)',
#  '18. American Horror Story (2011– )',
#  '19. Breaking Bad (2008–2013)',
#  '20. Lucifer (2016–2021)',
#  '21. Supernatural (2005–2020)',
#  '22. Prison Break (2005–2017)',
#  '23. How to Get Away with Murder (2014–2020)',
#  '24. Teen Wolf (2011–2017)',
#  '25. The Simpsons (1989– )',
#  '26. Once Upon a Time (2011–2018)',
#  '27. Narcos (2015–2017)',
#  '28. Daredevil (2015–2018)',
# ...

# %%
#let's extract all web elements having run time
time=[]
time_tags=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in time_tags:
    time.append(i.text)
time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
#let's extract all web elements having rating
rating=[]
rating_tags=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in rating_tags:
    rating.append(i.text)
rating
# Out:
# ['9.2',
#  '8.7',
#  '8.1',
#  '7.5',
#  '7.6',
#  '8.1',
#  '6.6',
#  '7.6',
#  '7.6',
#  '7.5',
#  '8.2',
#  '8.2',
#  '8.8',
#  '9.1',
#  '8.5',
#  '7.4',
#  '7.7',
#  '8',
#  '9.5',
#  '8.1',
#  '8.4',
#  '8.3',
#  '8.1',
#  '7.7',
#  '8.7',
#  '7.7',
#  '8.8',
#  '8.6',
#  '8.9',
#  '8.3',
#  '8.5',
#  '8.6',
#  '8.3',
#  '6.2',
#  '7.5',
#  '8.2',
#  '7.8',
#  '8.5',
#  '7.9',
#  '8.5',
#  '9.1',
#  '6.5',
#  '8.1',
#  '8.7',
#  '8.7',
#  '7.3',
#  '8.4',
#  '8.6',
#  '7.8',
#  '7.5',
#  '7.7',
#  '8.7',
#  '6.8',
#  '8.2',
#  '8',
#  '8.3',
#  '8.8',
#  '8.7',
#  '6.7',
#  '8.3',
#  '8.3',
#  '7.3',
#  '6.8',
#  '8.4',
#  '7.4',
#  '8.1',
#  '7.9',
#  '6.8',
#  '8.7',
#  '8.4',
#  '6.5',
#  '7.9',
#  '8.9',
#  '7.8',
#  '7.6',
#  '8.9',
#  '8.1',
#  '8.5',
#  '8.3',
#  '7.3',
#  '8.7',
#  '8.2',
#  '6.4',
#  '6.3',
#  '8.6',
#  '7.9',
#  '7.3',
#  '7.7',
#  '7.2',
#  '8.5',
#  '6.5',
#  '8.1',
#  '8.7',
#  '9.4',
#  '7.8',
#  '7.4',
#  '7.8',
#  '8.1',
#  '7.1',
#  '8.6']

# %%
#let's extract all web elements having votes and genre
votes=[]
votes_tags=driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]')
for i in votes_tags:
    votes.append(i.text)
votes
# Out:
# ['TV-MA | 57 min | Action, Adventure, Drama',
#  'Stars: Emilia Clarke, Peter Dinklage, Kit Harington, Lena Headey',
#  'Votes: 2,089,987',
#  'TV-14 | 51 min | Drama, Fantasy, Horror',
#  'Stars: Millie Bobby Brown, Finn Wolfhard, Winona Ryder, David Harbour',
#  'Votes: 1,179,545',
#  'TV-MA | 44 min | Drama, Horror, Thriller',
#  'Stars: Andrew Lincoln, Norman Reedus, Melissa McBride, Lauren Cohan',
#  'Votes: 988,902',
#  'TV-MA | 60 min | Drama, Mystery, Thriller',
#  'Stars: Dylan Minnette, Katherine Langford, Christian Navarro, Alisha Boe',
#  'Votes: 292,860',
#  'TV-14 | 43 min | Drama, Mystery, Sci-Fi',
#  'Stars: Eliza Taylor, Bob Morley, Marie Avgeropoulos, Isaiah Washington',
#  'Votes: 252,002',
#  'TV-MA | 59 min | Comedy, Crime, Drama',
#  'Stars: Taylor Schilling, Danielle Brooks, Taryn Manning, Emma Myles',
#  'Votes: 302,913',
#  'TV-14 | 45 min | Crime, Drama, Mystery',
#  'Stars: Lili Reinhart, Camila Mendes, Cole Sprouse, K.J. Apa',
#  'Votes: 145,513',
# ...

# %%
driver.close()

# %% [markdown]
# # ANS-10-A python program to scrape details of datasets from UCI machine learning repositories.

# %%
driver=webdriver.Chrome(r"C:\Users\OM RAJ PANDEY\Desktop\jupyter\chromedriver.exe")

# %%
#Let's maximize the automated chrome window
driver.maximize_window()

# %%
#Opening up archives.ics.uci.edu.com website on automated chrome window
url='https://archive.ics.uci.edu/'
driver.get(url)

# %%
#clicking the view button
view_btn=driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]')
view_btn.click()

# %%
#let's extract all web elements having names, Data type,Attribute type,NO of instances,No of attribute,year
names=[]
names_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
for i in names_tags:
    names.append(i.text)
names
# Out:
# ['Classification (466)\nRegression (151)\nClustering (121)\nOther (56)',
#  'Categorical (38)\nNumerical (422)\nMixed (55)',
#  'Multivariate (480)\nUnivariate (30)\nSequential (59)\nTime-Series (126)\nText (69)\nDomain-Theory (23)\nOther (21)',
#  'Life Sciences (147)\nPhysical Sciences (57)\nCS / Engineering (234)\nSocial Sciences (41)\nBusiness (45)\nGame (12)\nOther (81)',
#  'Less than 10 (166)\n10 to 100 (279)\nGreater than 100 (110)',
#  'Less than 100 (38)\n100 to 1000 (210)\nGreater than 1000 (339)',
#  'Matrix (439)\nNon-Matrix (183)',
#  'Table View  List View',
#  'Abalone',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '4177 ',
#  '8 ',
#  '1995 ',
#  'Adult',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer ',
#  '48842 ',
#  '14 ',
#  '1996 ',
#  'Annealing',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '798 ',
#  '38 ',
#  ' ',
#  'Anonymous Microsoft Web Data',
#  ' ',
# ...

# %%
driver.close()
